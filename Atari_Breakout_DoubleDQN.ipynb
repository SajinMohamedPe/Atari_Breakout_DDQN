# %% [markdown]
# Working on this implementation

# %%
import collections
import numpy as np
import gym
from PIL import Image
import torch

class DQNBreakout(gym.Wrapper):
    def __init__(self, render_mode='rgb_array', repeat=4, no_ops=0,
                 fire_first=False, stack_size=4, device='cpu'):
        super(DQNBreakout, self).__init__(gym.make("BreakoutNoFrameskip-v4", render_mode=None))
        self.repeat = repeat
        self.image_shape = (84, 84)
        self.stack_size = stack_size
        self.device = device
        self.no_ops = no_ops
        self.fire_first = fire_first
        self.frame_stack = collections.deque(maxlen=stack_size)
        self.lives = 0

    def reset(self):
        self.frame_stack.clear()
        observation = self.env.reset()
        self.lives = self.env.ale.lives()
        processed = self.process_observation(observation)
        for _ in range(self.stack_size):
            self.frame_stack.append(processed)
        return self.get_stacked_frames()

    def step(self, action):
        total_reward = 0
        done = False
        for _ in range(self.repeat):
            observation, reward, done, info = self.env.step(action)
            total_reward += reward
            if info['lives'] < self.lives:
                total_reward -= 1
                self.lives = info['lives']
            processed = self.process_observation(observation)
            self.frame_stack.append(processed)
            if done:
                break
        stacked_frames = self.get_stacked_frames()
        return stacked_frames, total_reward, done, info

    def process_observation(self, observation):
        img = Image.fromarray(observation)
        img = img.resize(self.image_shape)
        img = img.convert("L")
        img = np.array(img, dtype=np.float32) / 255.0
        img = np.expand_dims(img, axis=-1)
        
        return img

    # stacking farames
    def get_stacked_frames(self):
        # Stack along a new axis to create a single array from the deque of frames
        assert len(self.frame_stack) == self.stack_size, "The frame stack has not been fully initialized."
        stacked_frames = np.concatenate(list(self.frame_stack), axis=-1)
        return torch.from_numpy(stacked_frames).unsqueeze(0).to(self.device)  # Add batch dimension and send to device

# %%
from gym.wrappers import AtariPreprocessing, FrameStack
import keras 
from keras import layers
import tensorflow as tf 
import numpy as np
import gym as gym
import random
random.seed(2212)
np.random.seed(2212)
tf.random.set_seed(2212)
from collections import deque
input_shape = [2]

# %%
# Hyperparameters
EPISODES = 560
REPLAY_MEMORY_SIZE = 1_00_000
MINIMUM_REPLAY_MEMORY = 1_000
MINIBATCH_SIZE = 32
EPSILON = 1
EPSILON_DECAY = 0.99
MINIMUM_EPSILON = 0.001
DISCOUNT = 0.99
ENV_NAME = 'BreakoutNoFrameskip-v4'
EPSILON_RANDOM_FRAMES = 5000
MAX_STEPS_PER_EPISODE = 10000
UPDATE_AFTER_ACTIONS = 4
UPDATE_TARGET_NETWROK = 10000
MAX_EPISODES = 500


# Environment details
env = gym.make(ENV_NAME)
env = DQNBreakout(env)

# defining the input shape and the number of outputs from the environment
input_shape = env.observation_space.shape  # Assuming self.observation_dim is a tuple
n_outputs = env.action_space.n

num_actions = 4
def create_dueling_q_model():
    # Input layer (already adjusting to 'channels last')
    input_layer = layers.Input(shape=(84, 84,4))
    
    # Convolutional layers
    x = layers.Conv2D(32, 8, strides=4, activation="relu")(input_layer)
    x = layers.Conv2D(64, 4, strides=2, activation="relu")(x)
    x = layers.Conv2D(64, 3, strides=1, activation="relu")(x)
    
    # Flattening the last convolutional output
    x = layers.Flatten()(x)
    
    # Dueling streams
    # State value tower - V(s)
    state_value = layers.Dense(1024, activation='relu')(x)
    state_value = layers.Dropout(0.2)(state_value)
    state_value = layers.Dense(1024, activation='relu')(state_value)
    state_value = layers.Dropout(0.2)(state_value)
    state_value = layers.Dense(1, activation=None)(state_value)

    
    # Action advantage tower - A(s, a)
    action_advantage = layers.Dense(1024, activation='relu')(x)
    action_advantage = layers.Dropout(0.2)(action_advantage)
    action_advantage = layers.Dense(1024, activation='relu')(action_advantage)
    action_advantage = layers.Dense(num_actions, activation=None)(action_advantage)
    
    # Combine the state and action advantage to get the final Q-values
    # Q(s, a) = V(s) + (A(s, a) - mean(A(s, a)))
    q_values = layers.Lambda(lambda values: values[0] + (values[1] - tf.reduce_mean(values[1], axis=1, keepdims=True)),
                             output_shape=(num_actions,))([state_value, action_advantage])

    # Build the model
    model = keras.Model(inputs=input_layer, outputs=q_values)
    return model

model = create_dueling_q_model()
target_model1 = create_dueling_q_model()


# Compiling the neural network using Mean Square Error as loss function and
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=0.005))

from collections import deque
# Replay memory to store experiances of the model with the environment
replay_buffer = deque(maxlen=REPLAY_MEMORY_SIZE)

'''Defining epsilon greedy policy function to determine an action
to decide whether to explore or exploit the knowledge acquired'''
def epsilon_greedy_policy(state, epsilon, frame_count, episode):
    # if (frame_count == 59 and episode == 0):
    #     print(np.random.randint(0, num_actions))
    if np.random.uniform(0, 1) < epsilon or frame_count < EPSILON_RANDOM_FRAMES:
        action = np.random.randint(0, num_actions)
        return action
    else:
        ''' Look into Notebook'''
        state_tensor = keras.ops.convert_to_tensor(state)
        # state_tensor = keras.ops.expand_dims(state_tensor, 0)
        # if state_tensor.shape == (1, 1, 84, 84, 4):  # Check if there's an extra unwanted dimension
        #     state_tensor = tf.squeeze(state_tensor, axis=1)
        action_probs = model(state_tensor, training=False)
        # Take best action
        action = keras.ops.argmax(action_probs[0]).numpy()

        return action



'''This function samples a batch of experiences from the replay buffer for training the model.'''
def sample_experiences(batch_size):
    indices = np.random.randint(len(replay_buffer), size=batch_size)
    batch = [replay_buffer[index] for index in indices]
    return [
        np.array([experience[field_index] for experience in batch])
        for field_index in range(5)
    ] 

max_reward = -999999
'''This function defines the steps the agent has to take based on the epsilon greedy policy
 and accumulates the reward'''
# def play_one_step(env, state, epsilon, frame_count):
#     # defining reward acquired in each episode
#     global episode_reward
#     # Calling epsilon greedy function to select action
#     action = epsilon_greedy_policy(state, epsilon, frame_count)
#     # Executing the action and returns 4 values
#     next_state, reward, done, info = env.step(action)

#     # accumulating rewards in each step of the epsiode(max=-200)
#     episode_reward += reward

#     # append this result to the replay buffer(experince replay)
#     replay_buffer.append((state, action, reward, next_state, done))

#     return next_state, action, episode_reward, max_reward, done, info



rewards = []
best_score = 0

batch_size = 32
discount_factor = 0.95
optimizer = tf.keras.optimizers.Nadam(learning_rate=1e-1)
loss_fn = tf.keras.losses.mean_squared_error
 
def training_step(batch_size):
    if len(replay_buffer) < batch_size:
        return  # Ensure there's enough samples in the buffer

    # Randomly sample a batch of experiences from the replay buffer
    minibatch = random.sample(replay_buffer, batch_size)
    X_cur_states = np.array([sample[0] for sample in minibatch])
    X_next_states = np.array([sample[3] for sample in minibatch])

    X_cur_states = np.squeeze(X_cur_states, axis=1)
    X_next_states = np.squeeze(X_next_states, axis=1)
    
    # print("Shape of X_cur_states:", X_cur_states.shape)
    # print("Shape of X_next_states:", X_next_states.shape)

    # assert X_cur_states.ndim == 4 and X_next_states.ndim == 4
    cur_action_values = model.predict(X_cur_states, verbose =0)
    # next_action_values = target_model1.predict(X_next_states, verbose=0)
    
    next_action_values_main = model.predict(X_next_states, verbose=0)
    next_action_values_target = target_model1.predict(X_next_states, verbose=0)
    '''Update the Q values for the current state-action pairs based on the rewards 
       and the maximum predicted Q values for the next states'''
    for index, (cur_state, action, reward, next_state, done) in enumerate(minibatch):
        
        if not done:
            # Return action with highest Q value in next state as per the main neural network
            best_action_next = np.argmax(next_action_values_main[index])
            ''' The bellman equation is updated to to return Q value for the action taken using reward, 
            discount and best next action from the target network and not the main network'''
            cur_action_values[index][action] = reward + DISCOUNT * next_action_values_target[index][best_action_next]
        else:
            cur_action_values[index][action] = reward
    # updates model weights using Q values to minimize the error between target value and predicted value.
    model.fit(X_cur_states, cur_action_values, verbose=0)

q_values = []
positions = []
velocities = []
action_taken = []
frame_count = 0

def play_one_step(env, state, epsilon, frame_count, episode):
    action = epsilon_greedy_policy(state, epsilon, frame_count, episode)
    next_state, reward, done, info = env.step(action)
    # print("reward ", reward, "obtained at frame ", frame_count, "for action ", action, "with episode as", episode)
    global episode_reward
    episode_reward += reward
    replay_buffer.append((state, action, reward, next_state, done))
    return next_state, action, episode_reward, max_reward, done, info

for episode in range(MAX_EPISODES):
    
    # print(np.random.randint(0, num_actions))
    state = env.reset()
    state = np.array(state)
    episode_reward = 0 

    for timestep in range(MAX_STEPS_PER_EPISODE):
        frame_count += 1
        next_state, action, reward, max_reward, done, info = play_one_step(env, state, EPSILON, frame_count, episode)
        state = next_state

        if done:
            break  # Ensure correct handling at the end of an episode

        if len(replay_buffer) >= MINIMUM_REPLAY_MEMORY and frame_count % UPDATE_AFTER_ACTIONS == 0:
            training_step(batch_size)
    if(EPSILON > MINIMUM_EPSILON and len(replay_buffer) > MINIMUM_REPLAY_MEMORY):
        EPSILON *= EPSILON_DECAY
    max_reward = max(reward, max_reward)
    print('Episode', episode, 'Episodic Reward', reward, 'Maximum Reward', max_reward, 'EPSILON', EPSILON)
    rewards.append(reward)
    q_values.append(np.mean(model.predict(state, verbose=0)))
    
# Initialize lists to store Q-values, positions, velocities, and actions taken


    # Every 20 episodes, update the weights of the target model with the weights of the training model
    if frame_count % UPDATE_TARGET_NETWROK == 0:
        target_model1.set_weights(model.get_weights())
# Out:
# Episode 0 Episodic Reward -2.0 Maximum Reward -2.0 EPSILON 1
# Episode 1 Episodic Reward -5.0 Maximum Reward -2.0 EPSILON 1
# Episode 2 Episodic Reward -5.0 Maximum Reward -2.0 EPSILON 1
# Episode 3 Episodic Reward -4.0 Maximum Reward -2.0 EPSILON 1
# Episode 4 Episodic Reward -5.0 Maximum Reward -2.0 EPSILON 1
# Episode 5 Episodic Reward -4.0 Maximum Reward -2.0 EPSILON 0.99
# Episode 6 Episodic Reward -5.0 Maximum Reward -2.0 EPSILON 0.9801
# Episode 7 Episodic Reward -4.0 Maximum Reward -2.0 EPSILON 0.9702989999999999
# Episode 8 Episodic Reward -5.0 Maximum Reward -2.0 EPSILON 0.96059601
# Episode 9 Episodic Reward -4.0 Maximum Reward -2.0 EPSILON 0.9509900498999999
# Episode 10 Episodic Reward -5.0 Maximum Reward -2.0 EPSILON 0.9414801494009999
# Episode 11 Episodic Reward -5.0 Maximum Reward -2.0 EPSILON 0.9320653479069899
# Episode 12 Episodic Reward -5.0 Maximum Reward -2.0 EPSILON 0.92274469442792
# Episode 13 Episodic Reward -4.0 Maximum Reward -2.0 EPSILON 0.9135172474836407
# Episode 14 Episodic Reward -3.0 Maximum Reward -2.0 EPSILON 0.9043820750088043
# Episode 15 Episodic Reward 0.0 Maximum Reward 0.0 EPSILON 0.8953382542587163
# Episode 16 Episodic Reward -5.0 Maximum Reward 0.0 EPSILON 0.8863848717161291
# Episode 17 Episodic Reward -4.0 Maximum Reward 0.0 EPSILON 0.8775210229989678
# Episode 18 Episodic Reward -3.0 Maximum Reward 0.0 EPSILON 0.8687458127689781
# Episode 19 Episodic Reward -4.0 Maximum Reward 0.0 EPSILON 0.8600583546412883
# Episode 20 Episodic Reward -3.0 Maximum Reward 0.0 EPSILON 0.8514577710948754
# Episode 21 Episodic Reward -5.0 Maximum Reward 0.0 EPSILON 0.8429431933839266
# Episode 22 Episodic Reward -5.0 Maximum Reward 0.0 EPSILON 0.8345137614500874
# Episode 23 Episodic Reward -3.0 Maximum Reward 0.0 EPSILON 0.8261686238355865
# Episode 24 Episodic Reward -5.0 Maximum Reward 0.0 EPSILON 0.8179069375972307
# Episode 25 Episodic Reward -4.0 Maximum Reward 0.0 EPSILON 0.8097278682212583
# Episode 26 Episodic Reward -4.0 Maximum Reward 0.0 EPSILON 0.8016305895390458
# Episode 27 Episodic Reward -5.0 Maximum Reward 0.0 EPSILON 0.7936142836436553
# Episode 28 Episodic Reward -4.0 Maximum Reward 0.0 EPSILON 0.7856781408072188
# Episode 29 Episodic Reward -5.0 Maximum Reward 0.0 EPSILON 0.7778213593991465
# Episode 30 Episodic Reward -5.0 Maximum Reward 0.0 EPSILON 0.7700431458051551
# Episode 31 Episodic Reward -4.0 Maximum Reward 0.0 EPSILON 0.7623427143471035
# Episode 32 Episodic Reward -2.0 Maximum Reward 0.0 EPSILON 0.7547192872036325
# Episode 33 Episodic Reward -1.0 Maximum Reward 0.0 EPSILON 0.7471720943315961
# Episode 34 Episodic Reward -3.0 Maximum Reward 0.0 EPSILON 0.7397003733882802
# Episode 35 Episodic Reward -2.0 Maximum Reward 0.0 EPSILON 0.7323033696543974
# Episode 36 Episodic Reward -4.0 Maximum Reward 0.0 EPSILON 0.7249803359578534
# Episode 37 Episodic Reward -5.0 Maximum Reward 0.0 EPSILON 0.7177305325982748
# Episode 38 Episodic Reward -5.0 Maximum Reward 0.0 EPSILON 0.7105532272722921
# Episode 39 Episodic Reward -4.0 Maximum Reward 0.0 EPSILON 0.7034476949995692
# Episode 40 Episodic Reward -4.0 Maximum Reward 0.0 EPSILON 0.6964132180495735
# Episode 41 Episodic Reward -4.0 Maximum Reward 0.0 EPSILON 0.6894490858690777
# Episode 42 Episodic Reward -5.0 Maximum Reward 0.0 EPSILON 0.682554595010387
# Episode 43 Episodic Reward -5.0 Maximum Reward 0.0 EPSILON 0.6757290490602831
# Episode 44 Episodic Reward -2.0 Maximum Reward 0.0 EPSILON 0.6689717585696803
# Episode 45 Episodic Reward -4.0 Maximum Reward 0.0 EPSILON 0.6622820409839835
# Episode 46 Episodic Reward -3.0 Maximum Reward 0.0 EPSILON 0.6556592205741436
# Episode 47 Episodic Reward -3.0 Maximum Reward 0.0 EPSILON 0.6491026283684022
# Episode 48 Episodic Reward -3.0 Maximum Reward 0.0 EPSILON 0.6426116020847181
# Episode 49 Episodic Reward -3.0 Maximum Reward 0.0 EPSILON 0.6361854860638709
# Episode 50 Episodic Reward -5.0 Maximum Reward 0.0 EPSILON 0.6298236312032323
# Episode 51 Episodic Reward -3.0 Maximum Reward 0.0 EPSILON 0.6235253948912
# Episode 52 Episodic Reward -3.0 Maximum Reward 0.0 EPSILON 0.617290140942288
# Episode 53 Episodic Reward -2.0 Maximum Reward 0.0 EPSILON 0.6111172395328651
# Episode 54 Episodic Reward -3.0 Maximum Reward 0.0 EPSILON 0.6050060671375365
# Episode 55 Episodic Reward -1.0 Maximum Reward 0.0 EPSILON 0.5989560064661611
# Episode 56 Episodic Reward -2.0 Maximum Reward 0.0 EPSILON 0.5929664464014994
# Episode 57 Episodic Reward -1.0 Maximum Reward 0.0 EPSILON 0.5870367819374844
# Episode 58 Episodic Reward -4.0 Maximum Reward 0.0 EPSILON 0.5811664141181095
# Episode 59 Episodic Reward -2.0 Maximum Reward 0.0 EPSILON 0.5753547499769285
# Episode 60 Episodic Reward 2.0 Maximum Reward 2.0 EPSILON 0.5696012024771592
# Episode 61 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.5639051904523876
# Episode 62 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.5582661385478638
# Episode 63 Episodic Reward -5.0 Maximum Reward 2.0 EPSILON 0.5526834771623851
# Episode 64 Episodic Reward -2.0 Maximum Reward 2.0 EPSILON 0.5471566423907612
# Episode 65 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.5416850759668536
# Episode 66 Episodic Reward -4.0 Maximum Reward 2.0 EPSILON 0.536268225207185
# Episode 67 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.5309055429551132
# Episode 68 Episodic Reward -5.0 Maximum Reward 2.0 EPSILON 0.525596487525562
# Episode 69 Episodic Reward -2.0 Maximum Reward 2.0 EPSILON 0.5203405226503064
# Episode 70 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.5151371174238033
# Episode 71 Episodic Reward -4.0 Maximum Reward 2.0 EPSILON 0.5099857462495653
# Episode 72 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.5048858887870696
# Episode 73 Episodic Reward -2.0 Maximum Reward 2.0 EPSILON 0.4998370298991989
# Episode 74 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.49483865960020695
# Episode 75 Episodic Reward -1.0 Maximum Reward 2.0 EPSILON 0.4898902730042049
# Episode 76 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.48499137027416284
# Episode 77 Episodic Reward -2.0 Maximum Reward 2.0 EPSILON 0.4801414565714212
# Episode 78 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.475340042005707
# Episode 79 Episodic Reward -4.0 Maximum Reward 2.0 EPSILON 0.47058664158564995
# Episode 80 Episodic Reward -4.0 Maximum Reward 2.0 EPSILON 0.4658807751697934
# Episode 81 Episodic Reward -1.0 Maximum Reward 2.0 EPSILON 0.4612219674180955
# Episode 82 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.45660974774391455
# Episode 83 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.4520436502664754
# Episode 84 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.44752321376381066
# Episode 85 Episodic Reward 2.0 Maximum Reward 2.0 EPSILON 0.44304798162617254
# Episode 86 Episodic Reward -4.0 Maximum Reward 2.0 EPSILON 0.4386175018099108
# Episode 87 Episodic Reward -1.0 Maximum Reward 2.0 EPSILON 0.4342313267918117
# Episode 88 Episodic Reward -4.0 Maximum Reward 2.0 EPSILON 0.4298890135238936
# Episode 89 Episodic Reward -2.0 Maximum Reward 2.0 EPSILON 0.42559012338865465
# Episode 90 Episodic Reward -5.0 Maximum Reward 2.0 EPSILON 0.4213342221547681
# Episode 91 Episodic Reward -5.0 Maximum Reward 2.0 EPSILON 0.41712087993322045
# Episode 92 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.41294967113388825
# Episode 93 Episodic Reward -1.0 Maximum Reward 2.0 EPSILON 0.40882017442254937
# Episode 94 Episodic Reward -4.0 Maximum Reward 2.0 EPSILON 0.4047319726783239
# Episode 95 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.40068465295154065
# Episode 96 Episodic Reward -4.0 Maximum Reward 2.0 EPSILON 0.39667780642202527
# Episode 97 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.392711028357805
# Episode 98 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.38878391807422696
# Episode 99 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.3848960788934847
# Episode 100 Episodic Reward 0.0 Maximum Reward 2.0 EPSILON 0.38104711810454983
# Episode 101 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.37723664692350434
# Episode 102 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.37346428045426927
# Episode 103 Episodic Reward -4.0 Maximum Reward 2.0 EPSILON 0.36972963764972655
# Episode 104 Episodic Reward -2.0 Maximum Reward 2.0 EPSILON 0.36603234127322926
# Episode 105 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.36237201786049694
# Episode 106 Episodic Reward -4.0 Maximum Reward 2.0 EPSILON 0.358748297681892
# Episode 107 Episodic Reward -3.0 Maximum Reward 2.0 EPSILON 0.35516081470507305
# Episode 108 Episodic Reward -4.0 Maximum Reward 2.0 EPSILON 0.3516092065580223
# Episode 109 Episodic Reward -4.0 Maximum Reward 2.0 EPSILON 0.34809311449244207
# Episode 110 Episodic Reward -1.0 Maximum Reward 2.0 EPSILON 0.34461218334751764
# Episode 111 Episodic Reward 6.0 Maximum Reward 6.0 EPSILON 0.34116606151404244
# Episode 112 Episodic Reward -3.0 Maximum Reward 6.0 EPSILON 0.337754400898902
# Episode 113 Episodic Reward -2.0 Maximum Reward 6.0 EPSILON 0.334376856889913
# Episode 114 Episodic Reward 7.0 Maximum Reward 7.0 EPSILON 0.33103308832101386
# Episode 115 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.3277227574378037
# Episode 116 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.3244455298634257
# Episode 117 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.3212010745647914
# Episode 118 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.3179890638191435
# Episode 119 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.31480917318095203
# Episode 120 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.3116610814491425
# Episode 121 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.30854447063465107
# Episode 122 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.30545902592830454
# Episode 123 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.3024044356690215
# Episode 124 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.29938039131233124
# Episode 125 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.2963865873992079
# Episode 126 Episodic Reward 1.0 Maximum Reward 7.0 EPSILON 0.29342272152521587
# Episode 127 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.2904884943099637
# Episode 128 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.28758360936686406
# Episode 129 Episodic Reward 0.0 Maximum Reward 7.0 EPSILON 0.2847077732731954
# Episode 130 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.28186069554046345
# Episode 131 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.2790420885850588
# Episode 132 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.2762516676992082
# Episode 133 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.27348915102221616
# Episode 134 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.270754259511994
# Episode 135 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.26804671691687404
# Episode 136 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.2653662497477053
# Episode 137 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.2627125872502282
# Episode 138 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.2600854613777259
# Episode 139 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.2574846067639487
# Episode 140 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.2549097606963092
# Episode 141 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.2523606630893461
# Episode 142 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.24983705645845267
# Episode 143 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.24733868589386815
# Episode 144 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.24486529903492946
# Episode 145 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.24241664604458016
# Episode 146 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.23999247958413436
# Episode 147 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.23759255478829303
# Episode 148 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.2352166292404101
# Episode 149 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.232864462948006
# Episode 150 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.23053581831852593
# Episode 151 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.22823046013534068
# Episode 152 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.22594815553398728
# Episode 153 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.22368867397864742
# Episode 154 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.22145178723886094
# Episode 155 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.21923726936647234
# Episode 156 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.2170448966728076
# Episode 157 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.21487444770607952
# Episode 158 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.21272570322901874
# Episode 159 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.21059844619672854
# Episode 160 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.20849246173476127
# Episode 161 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.20640753711741366
# Episode 162 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.20434346174623952
# Episode 163 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.20230002712877712
# Episode 164 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.20027702685748935
# Episode 165 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.19827425658891445
# Episode 166 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.1962915140230253
# Episode 167 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.19432859888279505
# Episode 168 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.1923853128939671
# Episode 169 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.19046145976502743
# Episode 170 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.18855684516737714
# Episode 171 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.18667127671570335
# Episode 172 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.18480456394854633
# Episode 173 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.18295651830906087
# Episode 174 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.18112695312597027
# Episode 175 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.17931568359471056
# Episode 176 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.17752252675876345
# Episode 177 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.17574730149117582
# Episode 178 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.17398982847626407
# Episode 179 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.17224993019150142
# Episode 180 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.1705274308895864
# Episode 181 Episodic Reward 6.0 Maximum Reward 7.0 EPSILON 0.16882215658069055
# Episode 182 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.16713393501488363
# Episode 183 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.16546259566473479
# Episode 184 Episodic Reward 4.0 Maximum Reward 7.0 EPSILON 0.16380796970808745
# Episode 185 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.16216989001100657
# Episode 186 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.1605481911108965
# Episode 187 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.15894270919978754
# Episode 188 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.15735328210778965
# Episode 189 Episodic Reward 0.0 Maximum Reward 7.0 EPSILON 0.15577974928671176
# Episode 190 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.15422195179384465
# Episode 191 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.1526797322759062
# Episode 192 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.15115293495314713
# Episode 193 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.14964140560361566
# Episode 194 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.1481449915475795
# Episode 195 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.1466635416321037
# Episode 196 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.14519690621578268
# Episode 197 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.14374493715362485
# Episode 198 Episodic Reward 6.0 Maximum Reward 7.0 EPSILON 0.1423074877820886
# Episode 199 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.1408844129042677
# Episode 200 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.13947556877522502
# Episode 201 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.13808081308747278
# Episode 202 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.13670000495659804
# Episode 203 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.13533300490703207
# Episode 204 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.13397967485796175
# Episode 205 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.13263987810938213
# Episode 206 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.1313134793282883
# Episode 207 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.13000034453500542
# Episode 208 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.12870034108965536
# Episode 209 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.12741333767875881
# Episode 210 Episodic Reward 1.0 Maximum Reward 7.0 EPSILON 0.12613920430197123
# Episode 211 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.12487781225895152
# Episode 212 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.123629034136362
# Episode 213 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.12239274379499838
# Episode 214 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.1211688163570484
# Episode 215 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.11995712819347792
# Episode 216 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.11875755691154315
# Episode 217 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.11756998134242772
# Episode 218 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.11639428152900344
# Episode 219 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.11523033871371341
# Episode 220 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.11407803532657627
# Episode 221 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.11293725497331052
# Episode 222 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.1118078824235774
# Episode 223 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.11068980359934164
# Episode 224 Episodic Reward 0.0 Maximum Reward 7.0 EPSILON 0.10958290556334822
# Episode 225 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.10848707650771475
# Episode 226 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.1074022057426376
# Episode 227 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.10632818368521123
# Episode 228 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.10526490184835911
# Episode 229 Episodic Reward 6.0 Maximum Reward 7.0 EPSILON 0.10421225282987552
# Episode 230 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.10317013030157676
# Episode 231 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.10213842899856099
# Episode 232 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.10111704470857538
# Episode 233 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.10010587426148963
# Episode 234 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.09910481551887473
# Episode 235 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.09811376736368599
# Episode 236 Episodic Reward 1.0 Maximum Reward 7.0 EPSILON 0.09713262969004913
# Episode 237 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.09616130339314863
# Episode 238 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.09519969035921715
# Episode 239 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.09424769345562498
# Episode 240 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.09330521652106873
# Episode 241 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.09237216435585804
# Episode 242 Episodic Reward 6.0 Maximum Reward 7.0 EPSILON 0.09144844271229946
# Episode 243 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.09053395828517646
# Episode 244 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.08962861870232469
# Episode 245 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.08873233251530144
# Episode 246 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.08784500919014843
# Episode 247 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.08696655909824694
# Episode 248 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.08609689350726446
# Episode 249 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.08523592457219181
# Episode 250 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.0843835653264699
# Episode 251 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.0835397296732052
# Episode 252 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.08270433237647315
# Episode 253 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.08187728905270841
# Episode 254 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.08105851616218133
# Episode 255 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.08024793100055952
# Episode 256 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.07944545169055392
# Episode 257 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.07865099717364837
# Episode 258 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.07786448720191189
# Episode 259 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.07708584232989277
# Episode 260 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.07631498390659384
# Episode 261 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.07555183406752791
# Episode 262 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.07479631572685264
# Episode 263 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.07404835256958411
# Episode 264 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.07330786904388827
# Episode 265 Episodic Reward 1.0 Maximum Reward 7.0 EPSILON 0.07257479035344938
# Episode 266 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.07184904244991488
# Episode 267 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.07113055202541574
# Episode 268 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.07041924650516158
# Episode 269 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.06971505404010997
# Episode 270 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.06901790349970886
# Episode 271 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.06832772446471178
# Episode 272 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.06764444722006466
# Episode 273 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.066968002747864
# Episode 274 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.06629832272038537
# Episode 275 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.06563533949318151
# Episode 276 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.06497898609824969
# Episode 277 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.0643291962372672
# Episode 278 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.06368590427489453
# Episode 279 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.06304904523214558
# Episode 280 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.06241855477982412
# Episode 281 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.06179436923202588
# Episode 282 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.06117642553970562
# Episode 283 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.06056466128430856
# Episode 284 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.05995901467146548
# Episode 285 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.05935942452475082
# Episode 286 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.058765830279503314
# Episode 287 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.05817817197670828
# Episode 288 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.057596390256941195
# Episode 289 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.05702042635437178
# Episode 290 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.05645022209082806
# Episode 291 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.05588571986991978
# Episode 292 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.055326862671220584
# Episode 293 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.05477359404450838
# Episode 294 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.054225858104063294
# Episode 295 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.05368359952302266
# Episode 296 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.053146763527792434
# Episode 297 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.052615295892514506
# Episode 298 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.052089142933589364
# Episode 299 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.05156825150425347
# Episode 300 Episodic Reward 6.0 Maximum Reward 7.0 EPSILON 0.051052568989210935
# Episode 301 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.05054204329931883
# Episode 302 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.05003662286632564
# Episode 303 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.04953625663766238
# Episode 304 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.04904089407128576
# Episode 305 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.0485504851305729
# Episode 306 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.048064980279267165
# Episode 307 Episodic Reward 6.0 Maximum Reward 7.0 EPSILON 0.04758433047647449
# Episode 308 Episodic Reward 0.0 Maximum Reward 7.0 EPSILON 0.04710848717170975
# Episode 309 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.04663740229999265
# Episode 310 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.04617102827699272
# Episode 311 Episodic Reward 0.0 Maximum Reward 7.0 EPSILON 0.045709317994222794
# Episode 312 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.04525222481428057
# Episode 313 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.04479970256613776
# Episode 314 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.04435170554047638
# Episode 315 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.043908188485071616
# Episode 316 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.0434691066002209
# Episode 317 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.04303441553421869
# Episode 318 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.0426040713788765
# Episode 319 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.04217803066508773
# Episode 320 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.04175625035843686
# Episode 321 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.041338687854852486
# Episode 322 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.04092530097630396
# Episode 323 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.040516047966540916
# Episode 324 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.04011088748687551
# Episode 325 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.03970977861200675
# Episode 326 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.03931268082588668
# Episode 327 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.03891955401762781
# Episode 328 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.03853035847745153
# Episode 329 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.03814505489267701
# Episode 330 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.03776360434375024
# Episode 331 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.03738596830031274
# Episode 332 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.03701210861730961
# Episode 333 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.03664198753113651
# Episode 334 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.036275567655825146
# Episode 335 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.03591281197926689
# Episode 336 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.035553683859474224
# Episode 337 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.03519814702087948
# Episode 338 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.03484616555067068
# Episode 339 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.034497703895163975
# Episode 340 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.03415272685621234
# Episode 341 Episodic Reward 1.0 Maximum Reward 7.0 EPSILON 0.03381119958765021
# Episode 342 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.03347308759177371
# Episode 343 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.03313835671585597
# Episode 344 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.03280697314869741
# Episode 345 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.032478903417210436
# Episode 346 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.032154114383038335
# Episode 347 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.03183257323920795
# Episode 348 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.03151424750681587
# Episode 349 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.03119910503174771
# Episode 350 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.030887113981430233
# Episode 351 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.03057824284161593
# Episode 352 Episodic Reward 4.0 Maximum Reward 7.0 EPSILON 0.03027246041319977
# Episode 353 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.029969735809067772
# Episode 354 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.029670038450977095
# Episode 355 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.029373338066467324
# Episode 356 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.02907960468580265
# Episode 357 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.028788808638944622
# Episode 358 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.028500920552555174
# Episode 359 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.028215911347029624
# Episode 360 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.027933752233559327
# Episode 361 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.027654414711223735
# Episode 362 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.027377870564111496
# Episode 363 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.027104091858470382
# Episode 364 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.026833050939885677
# Episode 365 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.02656472043048682
# Episode 366 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.02629907322618195
# Episode 367 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.026036082493920133
# Episode 368 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.02577572166898093
# Episode 369 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.025517964452291122
# Episode 370 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.02526278480776821
# Episode 371 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.025010156959690527
# Episode 372 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.02476005539009362
# Episode 373 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.024512454836192684
# Episode 374 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.024267330287830756
# Episode 375 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.024024656984952448
# Episode 376 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.023784410415102923
# Episode 377 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.023546566310951894
# Episode 378 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.023311100647842375
# Episode 379 Episodic Reward 3.0 Maximum Reward 7.0 EPSILON 0.02307798964136395
# Episode 380 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.022847209744950314
# Episode 381 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.02261873764750081
# Episode 382 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.022392550271025803
# Episode 383 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.022168624768315544
# Episode 384 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.02194693852063239
# Episode 385 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.021727469135426065
# Episode 386 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.021510194444071803
# Episode 387 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.021295092499631085
# Episode 388 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.021082141574634772
# Episode 389 Episodic Reward 0.0 Maximum Reward 7.0 EPSILON 0.020871320158888425
# Episode 390 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.020662606957299542
# Episode 391 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.020455980887726547
# Episode 392 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.02025142107884928
# Episode 393 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.020048906868060788
# Episode 394 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.01984841779938018
# Episode 395 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.019649933621386378
# Episode 396 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.019453434285172513
# Episode 397 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.019258899942320787
# Episode 398 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.01906631094289758
# Episode 399 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.018875647833468602
# Episode 400 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.018686891355133916
# Episode 401 Episodic Reward 6.0 Maximum Reward 7.0 EPSILON 0.018500022441582577
# Episode 402 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.01831502221716675
# Episode 403 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.018131871994995084
# Episode 404 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.017950553275045134
# Episode 405 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.017771047742294682
# Episode 406 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.017593337264871736
# Episode 407 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.01741740389222302
# Episode 408 Episodic Reward 5.0 Maximum Reward 7.0 EPSILON 0.01724322985330079
# Episode 409 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.017070797554767782
# Episode 410 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.016900089579220106
# Episode 411 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.016731088683427906
# Episode 412 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.016563777796593626
# Episode 413 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.016398140018627688
# Episode 414 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.01623415861844141
# Episode 415 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.016071817032256998
# Episode 416 Episodic Reward 0.0 Maximum Reward 7.0 EPSILON 0.01591109886193443
# Episode 417 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.015751987873315085
# Episode 418 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.015594467994581935
# Episode 419 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.015438523314636115
# Episode 420 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.015284138081489753
# Episode 421 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.015131296700674856
# Episode 422 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.014979983733668108
# Episode 423 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.014830183896331426
# Episode 424 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.014681882057368112
# Episode 425 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.01453506323679443
# Episode 426 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.014389712604426485
# Episode 427 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.01424581547838222
# Episode 428 Episodic Reward 0.0 Maximum Reward 7.0 EPSILON 0.014103357323598397
# Episode 429 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.013962323750362413
# Episode 430 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.013822700512858789
# Episode 431 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.0136844735077302
# Episode 432 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.013547628772652899
# Episode 433 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.01341215248492637
# Episode 434 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.013278030960077106
# Episode 435 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.013145250650476335
# Episode 436 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.01301379814397157
# Episode 437 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.012883660162531854
# Episode 438 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.012754823560906535
# Episode 439 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.01262727532529747
# Episode 440 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.012501002572044496
# Episode 441 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.01237599254632405
# Episode 442 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.01225223262086081
# Episode 443 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.012129710294652202
# Episode 444 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.01200841319170568
# Episode 445 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.011888329059788623
# Episode 446 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.011769445769190737
# Episode 447 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.01165175131149883
# Episode 448 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.011535233798383842
# Episode 449 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.011419881460400004
# Episode 450 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.011305682645796004
# Episode 451 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.011192625819338045
# Episode 452 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.011080699561144665
# Episode 453 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.010969892565533218
# Episode 454 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.010860193639877886
# Episode 455 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.010751591703479106
# Episode 456 Episodic Reward 1.0 Maximum Reward 7.0 EPSILON 0.010644075786444315
# Episode 457 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.010537635028579873
# Episode 458 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.010432258678294073
# Episode 459 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.010327936091511133
# Episode 460 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.010224656730596022
# Episode 461 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.01012241016329006
# Episode 462 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.01002118606165716
# Episode 463 Episodic Reward -1.0 Maximum Reward 7.0 EPSILON 0.009920974201040588
# Episode 464 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.009821764459030182
# Episode 465 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.00972354681443988
# Episode 466 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.00962631134629548
# Episode 467 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.009530048232832525
# Episode 468 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.009434747750504199
# Episode 469 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.009340400272999157
# Episode 470 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.009246996270269165
# Episode 471 Episodic Reward 5.0 Maximum Reward 7.0 EPSILON 0.009154526307566474
# Episode 472 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.009062981044490808
# Episode 473 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.0089723512340459
# Episode 474 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.00888262772170544
# Episode 475 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.008793801444488386
# Episode 476 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.008705863430043502
# Episode 477 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.008618804795743068
# Episode 478 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.008532616747785637
# Episode 479 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.00844729058030778
# Episode 480 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.008362817674504702
# Episode 481 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.008279189497759654
# Episode 482 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.008196397602782058
# Episode 483 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.008114433626754238
# Episode 484 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.008033289290486696
# Episode 485 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.00795295639758183
# Episode 486 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.00787342683360601
# Episode 487 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.0077946925652699495
# Episode 488 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.00771674563961725
# Episode 489 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.007639578183221077
# Episode 490 Episodic Reward 2.0 Maximum Reward 7.0 EPSILON 0.0075631824013888665
# Episode 491 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.007487550577374978
# Episode 492 Episodic Reward -5.0 Maximum Reward 7.0 EPSILON 0.007412675071601228
# Episode 493 Episodic Reward -3.0 Maximum Reward 7.0 EPSILON 0.007338548320885215
# Episode 494 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.0072651628376763635
# Episode 495 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.0071925112092996
# Episode 496 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.007120586097206604
# Episode 497 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.007049380236234538
# Episode 498 Episodic Reward -2.0 Maximum Reward 7.0 EPSILON 0.006978886433872193
# Episode 499 Episodic Reward -4.0 Maximum Reward 7.0 EPSILON 0.006909097569533471

# %%
for _ in range(10):
    print(np.random.randint(0, num_actions))
# Out:
# 3
# 3
# 1
# 2
# 3
# 3
# 3
# 1
# 2
# 1

# %%
# model.set_weights(best_weights)
import matplotlib.pyplot as plt 
plt.figure(figsize=(8, 4))
plt.plot(q_values)
plt.xlabel("Episodes", fontsize=14)
plt.ylabel("Q values", fontsize=14)
plt.title("Q Value Convergence", fontsize=14)
plt.grid(True)
plt.show()

# %%
# model.set_weights(best_weights)
import matplotlib.pyplot as plt 
plt.figure(figsize=(8, 4))
plt.plot(rewards)
plt.xlabel("Episode", fontsize=14)
plt.ylabel("Reward", fontsize=14)
plt.title("Rewards vs. Episodes", fontsize=14)
plt.grid(True)
plt.show()

# %%
mean_rewards = np.zeros(1000)
for t in range(1000):
    mean_rewards[t] = np.mean(rewards[max(0, t-100):(t+1)])
plt.plot(mean_rewards)
plt.xlabel("Episode", fontsize=14)
plt.ylabel("Reward", fontsize=14)
plt.title("Moving average over 50 episodes with 5 window size", fontsize=14)
# Out:
# /Users/Sajin/Desktop/DQN_MountainCar/DQN_MountainCar/myenv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/Sajin/Desktop/DQN_MountainCar/DQN_MountainCar/myenv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Text(0.5, 1.0, 'Moving average over 50 episodes with 5 window size')

# %% [markdown]
# OLD IMplementation with error

# %%
import collections
import cv2
import gym
import numpy as np
from PIL import Image
import torch



class DQNBreakout(gym.Wrapper):

    def __init__(self, render_mode = 'rgb_array', repeat=4, no_ops=0,
                 fire_first=False, device='cpu'):
        env = gym.make("BreakoutNoFrameskip-v4", render_mode=None)

        super(DQNBreakout, self).__init__(env)

        self.repeat = repeat
        self.image_shape = (84,84)

        self.frame_buffer = []
        self.no_ops = no_ops
        self.fire_first = fire_first
        self.device = device
        self.lives = env.ale.lives()

    def step(self, action):
        total_reward = 0
        done = False

        # We're repeating for 4 actions to speed up training and
        # averaging over the last 2 to remove stutter in the Atari library.
        for i in range(self.repeat):
            observation, reward, done, info = self.env.step(action)

            total_reward += reward

            current_lives = info['lives']

            if current_lives < self.lives:
                total_reward = total_reward - 1
                self.lives = current_lives

                # print(f"Current reward: {total_reward} Lives: {self.lives}")

            self.frame_buffer.append(observation)

            if done:
                break

        max_frame = np.max(self.frame_buffer[-2:], axis=0)
        max_frame = self.process_observation(max_frame)
        max_frame = max_frame.to(self.device)

        total_reward = torch.tensor(total_reward).view(1, -1).float()
        total_reward = total_reward.to(self.device)

        done = torch.tensor(done).view(1, -1)
        done = done.to(self.device)

        return max_frame, total_reward, done, info

    def reset(self):
        self.frame_buffer = []
        observation = self.env.reset()

        self.lives = self.env.ale.lives()

        observation = self.process_observation(observation)

        return observation

    def process_observation(self, observation):

        img = Image.fromarray(observation)
        img = img.resize(self.image_shape)
        img = img.convert("L")
        img = np.array(img)
        img = torch.from_numpy(img)
        img = img.unsqueeze(0)
        img = img.unsqueeze(0)
        img = img / 255.0

        img = img.to(self.device)

        return img

# %%
from gym.wrappers import AtariPreprocessing, FrameStack
import keras 
from keras import layers
import tensorflow as tf 
import numpy as np
import gym as gym
import random
random.seed(2212)
np.random.seed(2212)
tf.random.set_seed(2212)
from collections import deque
input_shape = [2]


# Hyperparameters
EPISODES = 560
REPLAY_MEMORY_SIZE = 1_00_000
MINIMUM_REPLAY_MEMORY = 1_000
MINIBATCH_SIZE = 32
EPSILON = 1
EPSILON_DECAY = 0.99
MINIMUM_EPSILON = 0.001
DISCOUNT = 0.99
ENV_NAME = 'BreakoutNoFrameskip-v4'
EPSILON_RANDOM_FRAMES = 50000
MAX_STEPS_PER_EPISODE = 100
UPDATE_AFTER_ACTIONS = 4
UPDATE_TARGET_NETWROK = 10000
MAX_EPISODES = 50


# Environment details
env = gym.make(ENV_NAME)
# env = AtariPreprocessing(env)
# env = FrameStack(env,4)
env = DQNBreakout(env)

# action_dim = env.action_space.n
# observation_dim = env.observation_space.shape

# defining the input shape and the number of outputs from the environment
input_shape = env.observation_space.shape  # Assuming self.observation_dim is a tuple
n_outputs = env.action_space.n

# Creating a simple sequential neural network model with 3 layers (400, 300, 2)
# model = tf.keras.Sequential([
#     tf.keras.layers.Dense(400, activation='relu', input_shape=input_shape),
#     tf.keras.layers.Dense(300, activation='relu'),
#     tf.keras.layers.Dense(n_outputs, activation='linear')
# ])

num_actions = 4
def create_dueling_q_model():
    # Input layer (already adjusting to 'channels last')
    input_layer = layers.Input(shape=(84, 84,4))
    
    # Convolutional layers
    x = layers.Conv2D(32, 8, strides=4, activation="relu")(input_layer)
    x = layers.Conv2D(64, 4, strides=2, activation="relu")(x)
    x = layers.Conv2D(64, 3, strides=1, activation="relu")(x)
    
    # Flattening the last convolutional output
    x = layers.Flatten()(x)
    
    # Dueling streams
    # State value tower - V(s)
    state_value = layers.Dense(512, activation='relu')(x)
    state_value = layers.Dense(1, activation=None)(state_value)
    
    # Action advantage tower - A(s, a)
    action_advantage = layers.Dense(512, activation='relu')(x)
    action_advantage = layers.Dense(num_actions, activation=None)(action_advantage)
    
    # Combine the state and action advantage to get the final Q-values
    # Q(s, a) = V(s) + (A(s, a) - mean(A(s, a)))
    q_values = layers.Lambda(lambda values: values[0] + (values[1] - tf.reduce_mean(values[1], axis=1, keepdims=True)),
                             output_shape=(num_actions,))([state_value, action_advantage])

    # Build the model
    model = keras.Model(inputs=input_layer, outputs=q_values)
    return model

model = create_dueling_q_model()
target_model1 = create_dueling_q_model()

# Compiling the neural network using Mean Square Error as loss function and
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=0.005))

# Cloning the model to create a target model
# target_model1 = tf.keras.models.clone_model(model)

from collections import deque
# Replay memory to store experiances of the model with the environment
replay_buffer = deque(maxlen=REPLAY_MEMORY_SIZE)

'''Defining epsilon greedy policy function to determine an action
to decide whether to explore or exploit the knowledge acquired'''
def epsilon_greedy_policy(state, epsilon, frame_count):
    if np.random.uniform(0, 1) < epsilon or frame_count < EPSILON_RANDOM_FRAMES:
        action = np.random.randint(0, num_actions)
        return action
    else:
        ''' Look into Notebook'''
        # $# action = np.argmax(model.predict(np.expand_dims(state, axis=0), verbose=0)[0])
        state_tensor = keras.ops.convert_to_tensor(state)
        state_tensor = keras.ops.expand_dims(state_tensor, 0)
        action_probs = model(state_tensor, training=False)
        # Take best action
        action = keras.ops.argmax(action_probs[0]).numpy()

        return action

'''This function samples a batch of experiences from the replay buffer for training the model.'''
def sample_experiences(batch_size):
    indices = np.random.randint(len(replay_buffer), size=batch_size)
    batch = [replay_buffer[index] for index in indices]
    return [
        np.array([experience[field_index] for experience in batch])
        for field_index in range(5)
    ] 

max_reward = -999999
'''This function defines the steps the agent has to take based on the epsilon greedy policy
 and accumulates the reward'''
def play_one_step(env, state, epsilon, frame_count):
    # defining reward acquired in each episode
    global episode_reward
    # Calling epsilon greedy function to select action
    action = epsilon_greedy_policy(state, epsilon, frame_count)
    # Executing the action and returns 4 values
    next_state, reward, done, info = env.step(action)
   
    # $$# next_state = np.array(next_state)
    # accumulating rewards in each step of the epsiode(max=-200)
    episode_reward += reward
    # current_lives = info(lives)
    # truncating if the car reaches the flag on the mountain top within 200 steps
    # if done and episode_length < 200:
    #     # If episode is ended then we have won the game. Defining Stratagem to make the agent learn faster
    #     reward = 250 + episode_reward
    #     # save the model weights if we get a epsiode reward greater than maximum reward defined
    #     if(episode_reward > max_reward):
    #         print("Saving the model with reward", episode_reward)
    #         model.save_weights("agent"+str(episode_reward)+"_agent_.weights.h5")
    # else:
    #     # In oher cases reward will be proportional to the distance that car has travelled
    #     # from it's previous location + velocity of the car
    #     reward = 5*abs(next_state[0] - state[0]) + 3*abs(state[1])

    # append this result to the replay buffer(experince replay)
    replay_buffer.append((state, action, reward, next_state, done))

    return next_state, action, episode_reward, max_reward, done, info



np.random.seed(42)
tf.random.set_seed(42)
rewards = []
best_score = 0

batch_size = 32
discount_factor = 0.95
optimizer = tf.keras.optimizers.Nadam(learning_rate=1e-1)
loss_fn = tf.keras.losses.mean_squared_error

def training_step(batch_size):

    # Randomly sample a batch of experiences from the replay buffer
    minibatch = random.sample(replay_buffer, MINIBATCH_SIZE)
    # Initialize lists to store the current and next states
    X_cur_states = []
    X_next_states = []

    # Populate the current and next states lists with data from the sampled experiences
    for index, sample in enumerate(minibatch):
        cur_state, action, reward, next_state, done = sample
        
        
        X_cur_states.append(cur_state)
        X_next_states.append(next_state)
    # print("type of x cur state before array conversion", type(X_cur_states))
    # # Convert the lists to arrays
    # # print("shape of Cur_state", cur_state.shape)

    X_cur_states = np.array(X_cur_states)
    X_next_states = np.array(X_next_states)
    # print(X_cur_states)
    # X_cur_states = torch.tensor(X_cur_states)
    # X_next_states = torch.tensor(X_next_states)
    # # print("Shape of X_cur_states",X_cur_states.shape)
    
    
    # X_cur_states = X_cur_states.transpose(0, 2, 3, 1)
    # X_next_states = X_next_states.transpose(0, 2, 3, 1)

    
    # Initialize an array to store the Q values for the current state-action pairs
    cur_action_values = model.predict(X_cur_states, verbose =0)

    # Use the target model to predict the Q values for the next states
    next_action_values = target_model1.predict(X_next_states, verbose=0)
    
    '''Update the Q values for the current state-action pairs based on the rewards 
       and the maximum predicted Q values for the next states'''
    for index, sample in enumerate(minibatch):
        cur_state, action, reward, next_state, done = sample
        if not done:
            # if episode is not done then we have to calculate the Q value using Bellman's equation
            # Q(st, at) = rt + DISCOUNT * max(Q(s(t+1), a(t+1)))
            cur_action_values[index][action] = reward + DISCOUNT * np.amax(next_action_values[index])
        else:
            # if episode is done then Q value will be the reward
            # Q(st, at) = rt
            cur_action_values[index][action] = reward
            
    # train the agent with new Q values for the states and the actions
    model.fit(X_cur_states, cur_action_values, verbose=0)
    
# Initialize lists to store Q-values, positions, velocities, and actions taken
q_values = []
positions = []
velocities = []
actiion_taken = []
frame_count =0

# Loop through the episodes
for episode in range(MAX_EPISODES):
    # Reset the environment for the state to be reset
    state = env.reset()
    state = np.array(state) # $$# Will see for env.reset
    # done = False
    episode_reward = 0
    episode_length = 0

    # Run through different sets of steps untill 200 steps are completed or the car reaches the flag
    for timestep in range(1,MAX_STEPS_PER_EPISODE):
        frame_count += 1
        # Increment the episode length
        episode_length += 1

        # Play one step in the environment and get the next state, action, reward, max reward, done status, and info
        next_state, action, reward, max_reward, done, info  = play_one_step(env, state, EPSILON, frame_count)
        # Append the position, velocity, and action to their respective lists
        # positions.append(next_state[0])
        # velocities.append(next_state[1]) # $$# mgight need it later
        # actiion_taken.append(action)

        # Update the current state to the next state
        state = next_state

        # If the replay buffer is not large enough, skip the training step
        if(len(replay_buffer) < MINIMUM_REPLAY_MEMORY):
            continue
        elif (frame_count % UPDATE_AFTER_ACTIONS == 0):
            training_step(batch_size)

    print("training ends")

    # Update the maximum reward if the current reward is greater
    max_reward = max(reward, max_reward)

    # Print the episode number, episodic reward, maximum reward, and epsilon
    print('Episode', episode, 'Episodic Reward', reward, 'Maximum Reward', max_reward, 'EPSILON', EPSILON)
    rewards.append(reward)
    # state = np.array([(state)])
    # state= state.transpose(0, 2, 3, 1)
    # Append the mean Q-value of the current state to the Q-values list
    print("shape of state",state.shape)
    print("Type of state", type(state))
    # q_values.append(np.mean(model.predict((state), verbose=0)))

    state = state.permute(0, 2, 3, 1)  # Re-order the dimensions

    q_values.append(np.mean(model.predict(state, verbose=0)))
    
    # Every 20 episodes, update the weights of the target model with the weights of the training model
    if frame_count % UPDATE_TARGET_NETWROK == 0:
        target_model1.set_weights(model.get_weights())
    
    # If epsilon is greater than the minimum epsilon and the replay buffer is large enough, decay epsilon
    if(EPSILON > MINIMUM_EPSILON and len(replay_buffer) > MINIMUM_REPLAY_MEMORY):
        EPSILON *= EPSILON_DECAY

    if episode >= MAX_EPISODES:
        print("Stopped at eisode {}!".format(episode_length))
        break
# Out:
# training ends
# Episode 0 Episodic Reward tensor([[-1.]]) Maximum Reward tensor([[-1.]]) EPSILON 1
# shape of state torch.Size([1, 1, 84, 84])
# Type of state <class 'torch.Tensor'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 275
#     271 # q_values.append(np.mean(model.predict((state), verbose=0)))
#     273 state = state.permute(0, 2, 3, 1)  # Re-order the dimensions
# --> 275 q_values.append(np.mean(model.predict(state, verbose=0)))
#     277 # Every 20 episodes, update the weights of the target model with the weights of the training model
#     278 if frame_count % UPDATE_TARGET_NETWROK == 0:
#
# File c:\Users\91776\Desktop\Masters\UL\Modules\RL\venv\lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\91776\Desktop\Masters\UL\Modules\RL\venv\lib\site-packages\keras\src\layers\input_spec.py:227, in assert_input_compatibility(input_spec, inputs, layer_name)
#     222     for axis, value in spec.axes.items():
#     223         if value is not None and shape[axis] not in {
#     224             value,
#     225             None,
#     226         }:
# --> 227             raise ValueError(
#     228                 f'Input {input_index} of layer "{layer_name}" is '
#     229                 f"incompatible with the layer: expected axis {axis} "
#     230                 f"of input shape to have value {value}, "
#     231                 "but received input with "
#     232                 f"shape {shape}"
#     233             )
#     234 # Check shape.
#     235 if spec.shape is not None:
#
# ValueError: Exception encountered when calling Functional.call().
#
# Input 0 of layer "conv2d_72" is incompatible with the layer: expected axis -1 of input shape to have value 4, but received input with shape (1, 84, 84, 1)
#
# Arguments received by Functional.call():
#   • inputs=tf.Tensor(shape=(1, 84, 84, 1), dtype=float32)
#   • training=False
#   • mask=None

# %%
# model.set_weights(best_weights)
import matplotlib.pyplot as plt 
plt.figure(figsize=(8, 4))
plt.plot(q_values)
# plt.xlabel("Episode", fontsize=14)
# plt.ylabel("Reward", fontsize=14)
# plt.title("Rewards vs. Episodes", fontsize=14)
# plt.grid(True)
plt.show()

# %%
# model.set_weights(best_weights)
import matplotlib.pyplot as plt 
plt.figure(figsize=(8, 4))
plt.plot(rewards)
# plt.xlabel("Episode", fontsize=14)
# plt.ylabel("Reward", fontsize=14)
# plt.title("Rewards vs. Episodes", fontsize=14)
# plt.grid(True)
plt.show()

# %%
# model.set_weights(best_weights)
import matplotlib.pyplot as plt 
plt.figure(figsize=(8, 4))
plt.plot(episode_length)
# plt.xlabel("Episode", fontsize=14)
# plt.ylabel("Reward", fontsize=14)
# plt.title("Rewards vs. Episodes", fontsize=14)
# plt.grid(True)
plt.show()

# %%
# model.set_weights(best_weights)
import matplotlib.pyplot as plt 
plt.figure(figsize=(8, 4))
plt.plot(rewards)
plt.xlabel("Episode", fontsize=14)
plt.ylabel("Reward", fontsize=14)
plt.title("Rewards vs. Episodes", fontsize=14)
plt.grid(True)
plt.show()

# %%
mean_rewards = np.zeros(10)
for t in range(10):
    mean_rewards[t] = np.mean(rewards[max(0, t-5):(t+1)])
plt.plot(mean_rewards)
plt.xlabel("Episode", fontsize=14)
plt.ylabel("Reward", fontsize=14)
plt.title("Moving average over 50 episodes", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Moving average over 50 episodes')

# %% [markdown]
# https://github.com/SergeyGasparyan/ai-for-game-playing/blob/main/src/breakout_game.py

# %%
# import pygame as pg

# SCREEN_SIZE = 424, 430

# BRICK_HEIGHT, BRICK_WIDTH = 13, 32

# PADDLE_HEIGHT, PADDLE_WIDTH = 8, 50
# PADDLE_Y = SCREEN_SIZE[1] - PADDLE_HEIGHT - 10
# MAX_PADDLE_X = SCREEN_SIZE[0] - PADDLE_WIDTH

# BALL_DIAMETER = 12
# BALL_RADIUS = BALL_DIAMETER // 2
# MAX_BALL_X = SCREEN_SIZE[0] - BALL_DIAMETER
# MAX_BALL_Y = SCREEN_SIZE[1] - BALL_DIAMETER

# NUM_BRICKS_VERTICAL = 11
# NUM_BRICKS_HORIZONTAL = 12

# BLACK = (0, 0, 0)
# WHITE = (255, 255, 255)
# BLUE = (0, 0, 255)
# PADDLE_COLOR = (129, 133, 137)
# BRICK_COLOR = (153, 255, 204)

# FPS = 60

# pg.init()
# screen = pg.display.set_mode(SCREEN_SIZE)
# pg.display.set_caption("Breakout - Atari")
# clock = pg.time.Clock()


# class Breakout:
#     def __init__(self, vel=12):
#         self.capture = 0
#         self.vel = vel
#         self.ball_vel = [vel, -vel]
#         self.reward = 0.1
#         self.terminal = False

#         self.paddle = pg.Rect(
#             SCREEN_SIZE[1] // 2, PADDLE_Y, PADDLE_WIDTH, PADDLE_HEIGHT
#         )
#         self.ball = pg.Rect(
#             SCREEN_SIZE[1] // 2 + 10,
#             PADDLE_Y - BALL_DIAMETER,
#             BALL_DIAMETER,
#             BALL_DIAMETER,
#         )
#         self.create_bricks()

#     def create_bricks(self):
#         self.bricks = []
#         y_ofs = 20
#         for _ in range(NUM_BRICKS_VERTICAL):
#             x_ofs = 15

#             for _ in range(NUM_BRICKS_HORIZONTAL):
#                 self.bricks.append(pg.Rect(x_ofs, y_ofs, BRICK_WIDTH, BRICK_HEIGHT))
#                 x_ofs += BRICK_WIDTH + 1

#             y_ofs += BRICK_HEIGHT + 1

#     def draw_bricks(self):
#         for i, brick in enumerate(self.bricks):
#             pg.draw.rect(screen, BRICK_COLOR, brick)

#     def draw_paddle(self):
#         pg.draw.rect(screen, PADDLE_COLOR, self.paddle)

#     def draw_ball(self):
#         pg.draw.circle(
#             screen,
#             WHITE,
#             (self.ball.left + BALL_RADIUS, self.ball.top + BALL_RADIUS),
#             BALL_RADIUS,
#         )

#     def check_input(self, input_action):
#         # 0: LEFT, 1: Right
#         if input_action[0] == 1:
#             self.paddle.left -= self.vel
#             if self.paddle.left < 0:
#                 self.paddle.left = 0

#         elif input_action[1] == 1:
#             self.paddle.left += self.vel
#             if self.paddle.left > MAX_PADDLE_X:
#                 self.paddle.left = MAX_PADDLE_X

#     def move_ball(self):
#         self.ball.left += self.ball_vel[0]
#         self.ball.top += self.ball_vel[1]

#         if self.ball.left <= 0:
#             self.ball.left = 0
#             self.ball_vel[0] = -self.ball_vel[0]
#         elif self.ball.left >= MAX_BALL_X:
#             self.ball.left = MAX_BALL_X
#             self.ball_vel[0] = -self.ball_vel[0]

#         if self.ball.top < 0:
#             self.ball.top = 0
#             self.ball_vel[1] = -self.ball_vel[1]
#         elif self.ball.top >= MAX_BALL_Y:
#             self.ball.top = MAX_BALL_Y
#             self.ball_vel[1] = -self.ball_vel[1]

#     def take_action(self, input_action):
#         pg.event.pump()
#         for event in pg.event.get():
#             if event.type == pg.QUIT:
#                 pg.quit()
#                 quit()

#         screen.fill(BLACK)
#         self.check_input(input_action)
#         self.move_ball()

#         # Handle Collisions
#         for brick in self.bricks:
#             if self.ball.colliderect(brick):
#                 self.reward = 2
#                 self.ball_vel[1] = -self.ball_vel[1]
#                 self.bricks.remove(brick)
#                 break

#         if len(self.bricks) == 0:
#             self.terminal = True
#             self.__init__()

#         if self.ball.colliderect(self.paddle):
#             self.ball.top = PADDLE_Y - BALL_DIAMETER
#             self.ball_vel[1] = -self.ball_vel[1]
#         elif self.ball.top > self.paddle.top:
#             self.terminal = True
#             self.__init__()
#             self.reward = -2

#         self.draw_bricks()
#         self.draw_ball()
#         self.draw_paddle()

#         image_data = pg.surfarray.array3d(pg.display.get_surface())

#         pg.display.update()
#         clock.tick(FPS)

#         return image_data, self.reward, self.terminal
# Out:
# pygame 2.1.0 (SDL 2.0.16, Python 3.10.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import torch.nn as nn
import torch.nn.functional as F


class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()

        self.number_of_actions = 2
        self.gamma = 0.99
        self.final_epsilon = 0.05
        self.initial_epsilon = 0.1
        self.number_of_iterations = 2000000
        self.replay_memory_size = 750000
        self.minibatch_size = 32
        self.explore = 3000000

        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, 4, 2)
        self.conv3 = nn.Conv2d(64, 64, 3, 1)
        self.fc4 = nn.Linear(7 * 7 * 64, 512)
        self.fc5 = nn.Linear(512, self.number_of_actions)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.fc4(x.view(x.size(0), -1)))

        return self.fc5(x)

# %%
import torch
# import Breakout
from utils import device, preprocessing
from models import NeuralNetwork


def test(model):
    game_state = Breakout()

    # initial action is do nothing
    action = torch.zeros([model.number_of_actions], dtype=torch.float32).to(device)
    action[0] = 1
    image_data, _, _ = game_state.take_action(action)
    image_data = preprocessing(image_data)
    state = torch.cat((image_data, image_data, image_data, image_data)).unsqueeze(0)

    while True:
        # get output from the neural network
        output = model(state)[0]
        action = torch.zeros([model.number_of_actions], dtype=torch.float32)

        # get action
        action_index = torch.argmax(output)
        action[action_index] = 1

        # get next state
        image_data_1, _, _ = game_state.take_action(action)
        image_data_1 = preprocessing(image_data_1)
        state_1 = torch.cat((state.squeeze(0)[1:, :, :], image_data_1)).unsqueeze(0)

        # set state to be state_1
        state = state_1


if __name__ == "__main__":
    model = NeuralNetwork()
    model.load_state_dict(torch.load('model_weights/best.pth').state_dict())
    test(model.eval().to(device))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 3
#       1 import torch
#       2 # import Breakout
# ----> 3 from utils import device, preprocessing
#       4 from models import NeuralNetwork
#       7 def test(model):
#
# ModuleNotFoundError: No module named 'utils'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import os
import time
import torch
import random
import argparse
import numpy as np
import torch.nn as nn
import torch.optim as optim
from collections import deque
from models import NeuralNetwork
from breakout_game import Breakout
from utils import device, init_weights, preprocessing


def train(model, start, lr=0.0003, optim_name='adam', loss_name='mse', num_iter_save=1000):
    # define optimizer
    if optim_name == 'adam':
        optimizer = optim.Adam(model.parameters(), lr=lr)
    elif optim_name == 'sgd':
        optimizer = optim.SGD(model.parameters(), lr=lr)

    # initialize error loss
    if loss_name == 'mse':
        criterion = nn.MSELoss()
    elif loss_name == 'crossentropy':
        criterion = nn.CrossEntropyLoss()

    # instantiate game
    game_state = Breakout()

    # initialize replay memory
    replay_buffer = deque()

    # initial action
    action = torch.zeros([model.number_of_actions], dtype=torch.float32).to(device)
    image_data, reward, terminal = game_state.take_action(action)
    image_data = preprocessing(image_data)
    state = torch.cat((image_data, image_data, image_data, image_data)).unsqueeze(0)

    # initialize epsilon value
    epsilon = model.initial_epsilon
    iteration = 0

    # main infinite loop
    while iteration < model.number_of_iterations:
        # get output from the neural network
        output = model(state)[0] # Output size = torch.Size([2]) tensor([-0.0278,  1.7244]
        #output = model(state)

        # initialize action
        action = torch.zeros([model.number_of_actions], dtype=torch.float32)

        # epsilon greedy exploration
        random_action = random.random() <= epsilon

        # Pick action --> random or index of maximum q value
        action_index = [torch.randint(model.number_of_actions, torch.Size([]), dtype=torch.int)
                        if random_action
                        else torch.argmax(output)][0].to(device)

        action[action_index] = 1

        if epsilon > model.final_epsilon:
            epsilon -= (model.initial_epsilon - model.final_epsilon) / model.explore

        # get next state and reward
        image_data_1, reward, terminal = game_state.take_action(action)
        image_data_1 = preprocessing(image_data_1)

        state_1 = torch.cat((state.squeeze(0)[1:, :, :], image_data_1)).unsqueeze(0)
        action = action.unsqueeze(0)
        reward = torch.from_numpy(np.array([reward], dtype=np.float32)).unsqueeze(0).to(device)

        # save transition to replay memory
        replay_buffer.append((state, action, reward, state_1, terminal))

        # if replay memory is full, remove the oldest transition
        if len(replay_buffer) > model.replay_memory_size:
            replay_buffer.popleft()

        # sample random mini_batch
        # it picks k unique random elements, a sample, from a sequence: random.sample(population, k)
        mini_batch = random.sample(replay_buffer, min(len(replay_buffer), model.minibatch_size))

        # unpack mini_batch
        state_batch   = torch.cat(tuple(d[0] for d in mini_batch)).to(device)
        action_batch  = torch.cat(tuple(d[1] for d in mini_batch)).to(device)
        reward_batch  = torch.cat(tuple(d[2] for d in mini_batch)).to(device)
        state_1_batch = torch.cat(tuple(d[3] for d in mini_batch)).to(device)

        # get output for the next state
        output_1_batch = model(state_1_batch)

        # set y_j to r_j for terminal state, otherwise to r_j + gamma*max(Q) Target Q value Bellman equation.
        y_batch = torch.cat(tuple(reward_batch[i] if mini_batch[i][4]
                                  else reward_batch[i] + model.gamma * torch.max(output_1_batch[i])
                                  for i in range(len(mini_batch))))

        q_value = torch.sum(model(state_batch) * action_batch, dim=1)

        optimizer.zero_grad()
        y_batch = y_batch.detach()

        # calculate loss
        loss = criterion(q_value, y_batch)

        # do backward pass
        loss.backward()
        optimizer.step()

        # set state to be state_1
        state = state_1
        iteration += 1

        if iteration % num_iter_save == 0:
            print('Saving the model')
            torch.save(model, f"model_weights/model_{iteration}.pth")

        elapsed_time = time.time() - start
        elapsed_minutes = int(elapsed_time // 60)
        elapsed_seconds = int(elapsed_time % 60)

        print(f"Iteration: {iteration} Elapsed time: {elapsed_minutes}:{elapsed_seconds} epsilon: {epsilon:.5f} action: {action_index.cpu().item()} Reward: {reward.cpu().numpy()[0][0]:.1f}")


if __name__ == '__main__':
    parser = argparse.ArgumentParser()

    parser.add_argument('--lr', type=float, default=0.0003, help="learning rate")
    parser.add_argument('--optim', type=str, default='adam', help="optimzer: adam, or sgd")
    parser.add_argument('--loss', type=str, default='mse', help="loss function: mse, or cross_entropy")
    parser.add_argument('--num_iter_save', type=int, default=1000, help="number of iterations to save the model checkpoint")

    args = parser.parse_args()

    os.makedirs('model_weights/', exist_ok=True)
    model = NeuralNetwork()
    if os.path.exists('model_weights/best.pth'):
        model = torch.load('model_weights/best.pth')
    else:
        model.apply(init_weights)

    model = model.train().to(device)

    start = time.time()
    train(model, start, args.lr, args.optim, args.loss, args.num_iter_save)

# %%
import cv2
import torch
import torch.nn as nn
import numpy as np


device = 'cuda' if torch.cuda.is_available() else 'cpu'


def preprocessing(image):
	image_data = cv2.cvtColor(cv2.resize(image, (84, 84)), cv2.COLOR_BGR2GRAY)
	image_data[image_data > 0] = 255
	image_data = np.reshape(image_data,(84, 84, 1))
	image_tensor = image_data.transpose(2, 0, 1)
	image_tensor = image_tensor.astype(np.float32)
	image_tensor = torch.from_numpy(image_tensor).to(device)

	return image_tensor


def init_weights(m):
    if type(m) == nn.Conv2d or type(m) == nn.Linear:
        torch.nn.init.uniform(m.weight, -0.01, 0.01)
        m.bias.data.fill_(0.01)
